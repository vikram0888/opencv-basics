# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import os
from pathlib import Path

# %%
#reading images
filepath = str(Path("../imgs/beach.jpg"))
gray_scale_img = cv2.imread(filepath,0)
rgb_scale_img = cv2.imread(filepath)
type(gray_scale_img)
# Out:
# numpy.ndarray

# %%
cv2.imshow("demo",gray_scale_img) #demo is the window name
cv2.imshow("rgb_img",rgb_scale_img)
cv2.waitKey(0)
cv2.destroyAllWindows() #if u press any key it will close that window

# %%
cv2.imwrite('gray_scale_img.jpg', gray_scale_img) #to save this 'gray_scale_img' use this command
# Out:
# True

# %%
plt.imshow(rgb_scale_img) #cv2 reads in BGR format and matplolib uses RGB

# %%
## draw the shapes
rectangle_draw = cv2.rectangle(rgb_scale_img, (384,0),(510,128),(0,255,0),3) 
#(384,0)--> y value is zero -->  top-left corner , (510,128) --> bottom-right corner
#  #(0,255,0) --> green color rectangle #thickness 3
#https://docs.opencv.org/4.x/dc/da5/tutorial_py_drawing_functions.html  ##refer this 
cv2.imshow("rectangle_draw", rectangle_draw)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
font = cv2.FONT_ITALIC
rectangle_draw = cv2.rectangle(rgb_scale_img, (384,0),(510,128),(0,255,0),3) 
cv2.putText(rectangle_draw, "Rectangle", (384+3,0+300),font,4,(255,0,0)) 
#"Rectangle" is ur class name  ##thickness is 4 ##color (255,0,0)
cv2.imshow("rectangle_draw", rectangle_draw)
cv2.waitKey(0)
cv2.destroyAllWindows()
